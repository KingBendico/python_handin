# %% [markdown]
# # Handin week 7
#
# ## Exercise 1
# Create a Python module with a class called Webscraper that implements an init(self,URL) and functions that use Selenium, BeautifulSoup and Regex needed to solve Exercise 2 (and 3). Furthermore, let the data be stored in class variables, so that results are easily accessed via objects.
#
# ## Exercise 2
# 1. Import your module to your Jupyter notebook.
# 2. Make an instance of your class with the following url: https://www.pricerunner.dk/cl/37/Grafikkort
# 3. Find graphics cards from Nvidia.
# 4. Find the most popular graphics processing unit (2080, 3070, etc.).
# 5. Store the result in a local dataset.
#
# ## Exercise 3
# 1. Given the result from exercise 2, find the five cheapest cards across brands, and show them in a plot chart, with ‘name’ on the x-axis and ‘price’ on the y-axis.
# 2. For the cheapest card, find out which dealers are trading it, and what the average price is. (Hint: new search/webscrape)
# 3. Find the brand with the GPU that has the biggest difference in list price.
#
# ### By Group 1, E:
# - Benjamin Choleva (cph-bc105@cphbusiness.dk)
# - Nicolas Malte Johan Allesøe (cph-na157@cphbusiness.dk)
# - Christoffer Kofoed Foldager (cph-cf161@cphbusiness.dk)
# - Andreas Maxim Arenfeldt Andersen (cph-aa344@cphbusiness.dk)

# %% [markdown]
# ## Status
# Finished EX 1 and 2. Didnt prioritize EX 3, as it doesnt deal with webscrabing.

# %% [markdown]
# ## Solution Ex1

# %%
from modules import w7
import importlib
importlib.reload(w7)
scrape = w7.Webscraper("https://www.pricerunner.dk/cl/37/Grafikkort%22")
scrape.search("NVidia")
scrape.cards
# Out:
# Initialzin webdriver
# Lets go!
# Fetching url
# Telling browser to wait 2 sec by deault
# Rejecting cookies
# Finding Nvidea cards
# Consulting the 'most popular searches' div to find the most popular processor
# Seems like the most popular card is: https://www.pricerunner.dk/sp/nvidia-geforce-rtx-3060-ti.html
# 0:06:53.040266
#                                        Graphics Cards        Price
# 0                    ASUS GeForce RTX 3060 Ti Dual OC    5.250 kr.
# 1       ASUS GeForce RTX 3060 Ti Dual 2xHDMI 3xDP 8GB    3.299 kr.
# 2   ASUS GeForce RTX 3060 Ti TUF Gaming 2xHDMI 3xD...    4.099 kr.
# 3                MSI GeForce RTX 3060 Ti Ventus 3X OC    5.650 kr.
# 4              Gigabyte Geforce RTX 3060 Ti 8GB EAGLE    4.460 kr.
# 5   Inno3D GeForce RTX 3060 Ti Twin X2 OC HDMI 3xD...    4.499 kr.
# 6              MSI GeForce RTX 3060 Ti Ventus 2X OCV1    4.199 kr.
# 7               MSI GeForce RTX 3060 Ti Gaming X Trio    6.150 kr.
# 8     EVGA GeForce RTX 3060 Ti XC Black HDMI 3xDP 8GB  109.290 kr.
# 9                MSI GeForce RTX 3060 Ti Ventus 2X OC    4.199 kr.
# 10  ASUS GeForce RTX 3060 Ti ROG Strix Gaming OC 2...    4.899 kr.
# 11   ASUS GeForce RTX 3060 Ti Dual Mini HDMI 3xDP 8GB    3.999 kr.
# 12  ASUS GeForce RTX 3060 Ti TUF Gaming OC 2xHDMI ...    5.550 kr.
# 13          Gigabyte GeForce RTX 3060 Ti Gaming OC 8G    5.450 kr.
# 14   Inno3D GeForce RTX 3060 Ti Twin X2 HDMI 3xDP 8GB    4.068 kr.
# 15          Gigabyte GeForce RTX 3060 Ti Eagle OC 8GB    5.150 kr.
# 16       Gigabyte Aorus GeForce RTX 3060 Ti Master 8G    6.450 kr.
# 17     MSI GeForce RTX 3060 Ti Gaming X HDMI 3xDP 8GB    5.841 kr.
# 18  ASUS GeForce RTX 3060 Ti Dual Mini OC HDMI 3xD...    4.199 kr.
# 19  PNY GeForce RTX 3060 Ti XLR8 Gaming Epic-X P H...    6.024 kr.
# 20  Inno3D GeForce RTX 3060 Ti iChill X3 Red HDMI ...    4.799 kr.
# 21  ASUS GeForce RTX 3060 Ti ROG Strix Gaming 2xHD...    4.899 kr.
# 22  EVGA GeForce RTX 3060 Ti FTW3 Ultra HDMI 3xDP 8GB    5.270 kr.
# 23         Gigabyte GeForce RTX 3060 Ti Vision OC 8GB    5.550 kr.
# 24      Gigabyte GeForce RTX 3060 Ti Gaming OC Pro 8G    5.550 kr.
# 25          EVGA GeForce RTX 3060 Ti XC HDMI 3xDP 8GB    6.007 kr.
# 26  Zotac GeForce RTX 3060 Ti Twin Edge OC HDMI 3x...    5.299 kr.
# 27  Palito GeForce RTX 3060 Ti GamingPro HDMI 3xDP...    6.073 kr.
# 28                EVGA GeForce RTX 3060 Ti FTW3 Black    6.752 kr.
# 29        Palit Microsystems GeForce RTX 3060 Ti Dual    4.991 kr.
# 30        EVGA GeForce RTX 3060 Ti FTW3 HDMI 3xDP 8GB    7.093 kr.
# 31  Palit Microsystems GeForce RTX 3060 Ti Dual OC...    4.994 kr.
# 32     PNY GeForce RTX 3060 Ti Dual Fan HDMI 3xDP 8GB    5.671 kr.
# 33           Inno3D GeForce RTX 3060 Ti iChill X3 RED    5.899 kr.
# 34  Ångström X-ray Core I5 16gb 1,024gb Ssd Nvidia...   13.999 kr.
# 35  ASUS TUF-RTX3060TI-O8G-GAMING - NVIDIA RTX3060...    5.999 kr.
# 36  AWD MB311 Ryzen 3800X 8 Core 4.5GHz NVIDIA RTX...    8.677 kr.
# 37  AWD P400A DRGB Ryzen 5600X 6 Core 4.6GHz NVIDI...    9.110 kr.
# 38  AWD Observatory Lite Mesh 3500X Six Core 4.1GH...    8.664 kr.
# 39   RTX 3060TI GAMING REVEL EPIC-X 8GB GDDR6 HDMI DP    5.506 kr.
